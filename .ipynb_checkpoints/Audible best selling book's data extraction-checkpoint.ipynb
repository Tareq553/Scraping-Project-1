# %% [markdown]
# # Library Insertion

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # Main Code Portion

# %%
#Checking the url
url = 'https://www.audible.com/adblbestsellers?page=1'
data = requests.get(url)
soup = BeautifulSoup(data.content, 'html.parser')
#print(soup.prettify())

# %%
#Total Page Finding
total_page=soup.select_one('div.bc-col-responsive.bc-text-right.bc-col-8 > div > span > ul > li:nth-child(5) > a').text.strip()
total_page
# Out:
# '5'

# %%
lst=[]

# %%
for i in range(1,int(total_page)+1):
    print(f'Running page no--{i}')
    url = f'https://www.audible.com/adblbestsellers?page={i}'
    data = requests.get(url)
    soup = BeautifulSoup(data.content, 'html.parser')
    main_field=soup.select_one("#product-list-a11y-skiplink-target")
    contents=main_field.select("li.bc-list-item.productListItem")
    for i, content in enumerate(contents):
        try:
            book_name=content.select_one('li:nth-child(1) > h3 > a').text.strip()
        except:
            book_name='No book name'
        try:
            author_name=content.select_one('li.bc-list-item.authorLabel > span > a').text.strip()
        except:
            author_name='No author name'
        try:
            narrated_by=content.select_one('li.bc-list-item.narratorLabel > span > a').text.strip()
        except:
            narrated_by='No narrator name'
        try:
            length=content.select_one('li.bc-list-item.runtimeLabel > span').text.strip()
        except:
            length='No length mentioned'
        try:
            release_date=content.select_one('li.bc-list-item.releaseDateLabel > span').text.strip()
        except:
            release_date='No release date mentioned'
        try:
            language=content.select_one('li.bc-list-item.languageLabel > span').text.strip()
        except:
            language='No language mentioned'
        try:
            rating=content.select_one('li.bc-list-item.ratingsLabel > span.bc-text.bc-size-small.bc-color-secondary').text.strip()
        except:
            rating='No rating mentioned'
        try:
            price=content.select(f'#buybox-regular-price-{i} > span:nth-child(2)')
        except:
            price='No price mentioned'
        f={
            'Book_name':book_name,
            'Author_name':author_name,
            'Narrated_by':narrated_by,
            'Length':length,
            'Release_date':release_date,
            'Language':language,
            'Rating':rating,
            'Price':price
        }
        lst.append(f)
# Out:
# Running page no--1
# Running page no--2
# Running page no--3
# Running page no--4
# Running page no--5

# %% [markdown]
# # DataFrame Generation

# %%
pd.DataFrame(lst)
# Out:
#                                             Book_name  \
# 0                                               Spare
# 1                                       Atomic Habits
# 2                                Lessons in Chemistry
# 3                               Daisy Jones & The Six
# 4                                      Never Finished
# ..                                                ...
# 95  The Five Love Languages: The Secret to Love Th...
# 96                                      Die with Zero
# 97                                         November 9
# 98                             Hell Divers X: Fallout
# 99                                The Untethered Soul
#
#                         Author_name                      Narrated_by  \
# 0   Prince Harry The Duke of Sussex  Prince Harry The Duke of Sussex
# 1                       James Clear                      James Clear
# 2                     Bonnie Garmus                   Miranda Raison
# 3               Taylor Jenkins Reid                   Jennifer Beals
# 4                     David Goggins                    David Goggins
# ..                              ...                              ...
# 95                     Gary Chapman                     Gary Chapman
# 96                     Bill Perkins                     Bill Perkins
# 97                   Colleen Hoover                   Zachary Webber
# 98          Nicholas Sansbury Smith                       R. C. Bray
# 99                Michael A. Singer                    Peter Berkrot
#
#                         Length  \
# 0   Length: 15 hrs and 39 mins
# 1    Length: 5 hrs and 35 mins
# 2   Length: 11 hrs and 55 mins
# 3     Length: 9 hrs and 3 mins
# 4    Length: 11 hrs and 6 mins
# ..                         ...
# 95   Length: 4 hrs and 46 mins
# 96   Length: 5 hrs and 11 mins
# 97   Length: 9 hrs and 46 mins
# 98  Length: 12 hrs and 58 mins
# 99   Length: 6 hrs and 11 mins
#
#                                          Release_date  \
# 0   Release date:\n                               ...
# 1   Release date:\n                               ...
# 2   Release date:\n                               ...
# 3   Release date:\n                               ...
# 4   Release date:\n                               ...
# ..                                                ...
# 95  Release date:\n                               ...
# 96  Release date:\n                               ...
# 97  Release date:\n                               ...
# 98  Release date:\n                               ...
# 99  Release date:\n                               ...
#
#                                              Language           Rating Price
# 0   Language:\n                                   ...   54,835 ratings    []
# 1   Language:\n                                   ...  124,134 ratings    []
# 2   Language:\n                                   ...   18,694 ratings    []
# 3   Language:\n                                   ...   34,844 ratings    []
# 4   Language:\n                                   ...   21,885 ratings    []
# ..                                                ...              ...   ...
# 95  Language:\n                                   ...   41,141 ratings    []
# 96  Language:\n                                   ...      335 ratings    []
# 97  Language:\n                                   ...   20,923 ratings    []
# 98  Language:\n                                   ...      275 ratings    []
# 99  Language:\n                                   ...   28,605 ratings    []
#
# [100 rows x 8 columns]

# %% [markdown]
# # CSV Generation

# %%
pd.DataFrame(lst).to_csv('Audible Best Selling Books.csv',index=False)
