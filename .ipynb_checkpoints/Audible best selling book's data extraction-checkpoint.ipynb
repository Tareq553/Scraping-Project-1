# %% [markdown]
# # Library Insertion

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # Main Code Portion

# %%
#Checking the url
url = 'https://www.audible.com/adblbestsellers?page=1'
data = requests.get(url)
soup = BeautifulSoup(data.content, 'html.parser')
#print(soup.prettify())

# %%
#Total Page Finding
total_page=soup.select_one('div.bc-col-responsive.bc-text-right.bc-col-8 > div > span > ul > li:nth-child(5) > a').text.strip()
total_page
# Out:
# '5'

# %%
lst=[]

# %%
for i in range(1,int(total_page)):
    print(f'Running page no--{i}')
    url = f'https://www.audible.com/adblbestsellers?page={i}'
    data = requests.get(url)
    soup = BeautifulSoup(data.content, 'html.parser')
    main_field=soup.select_one("#product-list-a11y-skiplink-target")
    contents=main_field.select("li.bc-list-item.productListItem")
    for content in contents:
        try:
            book_name=content.select_one('li:nth-child(1) > h3 > a').text.strip()
        except:
            book_name='No book name'
        try:
            author_name=content.select_one('li.bc-list-item.authorLabel > span > a').text.strip()
        except:
            author_name='No author name'
        try:
            narrated_by=content.select_one('li.bc-list-item.narratorLabel > span > a').text.strip()
        except:
            narrated_by='No narrator name'
        try:
            length=content.select_one('li.bc-list-item.runtimeLabel > span').text.strip()
        except:
            length='No length mentioned'
        try:
            release_date=content.select_one('li.bc-list-item.releaseDateLabel > span').text.strip()
        except:
            release_date='No release date mentioned'
        try:
            language=content.select_one('li.bc-list-item.languageLabel > span').text.strip()
        except:
            language='No language mentioned'
        try:
            rating=content.select_one('li.bc-list-item.ratingsLabel > span.bc-text.bc-size-small.bc-color-secondary').text.strip()
        except:
            rating='No rating mentioned'
        try:
            price=content.select('span.bc-text.bc-size-base.bc-color-base> span:nth-child(2)')
        except:
            price='No price mentioned'
        f={
            'Book_name':book_name,
            'Author_name':author_name,
            'Narrated_by':narrated_by,
            'Length':length,
            'Release_date':release_date,
            'Language':language,
            'Rating':rating,
            'Price':price
        }
        lst.append(f)
# Out:
# Running page no--1
# Running page no--2
# Running page no--3
# Running page no--4

# %% [markdown]
# # DataFrame Generation

# %%
pd.DataFrame(lst)
# Out:
#                                    Book_name                      Author_name  \
# 0                                      Spare  Prince Harry The Duke of Sussex
# 1                              Atomic Habits                      James Clear
# 2                       Lessons in Chemistry                    Bonnie Garmus
# 3                      Daisy Jones & The Six              Taylor Jenkins Reid
# 4                             The Last Party                 Clare Mackintosh
# ..                                       ...                              ...
# 155                                 Becoming                   Michelle Obama
# 156                   A Most Intriguing Lady                   Sarah Ferguson
# 157                    What Happened to You?                    Oprah Winfrey
# 158  The 7 Habits of Highly Effective People                 Stephen R. Covey
# 159                            The Alchemist                     Paulo Coelho
#
#                          Narrated_by                      Length  \
# 0    Prince Harry The Duke of Sussex  Length: 15 hrs and 39 mins
# 1                        James Clear   Length: 5 hrs and 35 mins
# 2                     Miranda Raison  Length: 11 hrs and 55 mins
# 3                     Jennifer Beals    Length: 9 hrs and 3 mins
# 4              Chloe Angharad Davies  Length: 13 hrs and 17 mins
# ..                               ...                         ...
# 155                   Michelle Obama   Length: 19 hrs and 3 mins
# 156                   Sarah Ferguson  Length: 12 hrs and 17 mins
# 157                   Bruce D. Perry   Length: 8 hrs and 27 mins
# 158                 Stephen R. Covey   Length: 13 hrs and 4 mins
# 159                     Jeremy Irons               Length: 4 hrs
#
#                                           Release_date  \
# 0    Release date:\n                               ...
# 1    Release date:\n                               ...
# 2    Release date:\n                               ...
# 3    Release date:\n                               ...
# 4    Release date:\n                               ...
# ..                                                 ...
# 155  Release date:\n                               ...
# 156  Release date:\n                               ...
# 157  Release date:\n                               ...
# 158  Release date:\n                               ...
# 159  Release date:\n                               ...
#
#                                               Language           Rating  \
# 0    Language:\n                                   ...   54,680 ratings
# 1    Language:\n                                   ...  124,109 ratings
# 2    Language:\n                                   ...   18,657 ratings
# 3    Language:\n                                   ...   34,811 ratings
# 4    Language:\n                                   ...      188 ratings
# ..                                                 ...              ...
# 155  Language:\n                                   ...  179,707 ratings
# 156  Language:\n                                   ...         1 rating
# 157  Language:\n                                   ...   19,880 ratings
# 158  Language:\n                                   ...   38,831 ratings
# 159  Language:\n                                   ...   78,510 ratings
#
#                                                  Price
# 0    [[Regular price: ], [\n            $24.95\n   ...
# 1    [[Regular price: ], [\n            $16.72\n   ...
# 2    [[Regular price: ], [\n            $17.92\n   ...
# 3    [[Regular price: ], [\n            $15.74\n   ...
# 4    [[Regular price: ], [\n            $18.26\n   ...
# ..                                                 ...
# 155                                                 []
# 156                                                 []
# 157                                                 []
# 158                                                 []
# 159                                                 []
#
# [160 rows x 8 columns]

# %% [markdown]
# # CSV Generation

# %%
pd.DataFrame(lst).to_csv('Audible Best Selling Books.csv',index=False)
